# %% [markdown]
# https://medium.com/@erikhallstrm/hello-world-rnn-83cd7105b767

# %%
from __future__ import print_function, division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

num_epochs = 100
total_series_length = 50000
truncated_backprop_length = 15 ##eqiuvalent to no of layers
state_size = 4 ## equivalent to no of nodes in each layer and input feature size eqvlnt to state_size+1
num_classes = 2 ## one hot encoded output
echo_step = 3 ##
batch_size = 5 ## no of rows in matrix
num_batches = total_series_length//batch_size//truncated_backprop_length

# %%
def generateData():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1))  # The first index changing slowest, subseries as rows
    y = y.reshape((batch_size, -1))

    return (x, y)

# %%
batchX_placeholder = tf.placeholder(tf.float32, [batch_size, truncated_backprop_length])
batchY_placeholder = tf.placeholder(tf.int32, [batch_size, truncated_backprop_length])

init_state = tf.placeholder(tf.float32, [batch_size, state_size])

# %%
W = tf.Variable(np.random.rand(state_size+1, state_size), dtype=tf.float32)
b = tf.Variable(np.zeros((1,state_size)), dtype=tf.float32)

W2 = tf.Variable(np.random.rand(state_size, num_classes),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,num_classes)), dtype=tf.float32)

# %%
inputs_series = tf.unstack(batchX_placeholder, axis=1)
labels_series = tf.unstack(batchY_placeholder, axis=1)

# %%
# Forward pass
current_state = init_state
states_series = []
for current_input in inputs_series:
    current_input = tf.reshape(current_input, [batch_size, 1])
    input_and_state_concatenated = tf.concat([current_input, current_state], 1)  # Increasing number of columns

    next_state = tf.tanh(tf.matmul(input_and_state_concatenated, W) + b)  # Broadcasted addition
    states_series.append(next_state)
    current_state = next_state

# %%
## instead of above two cells we can use the same using tf apis

# Unpack columns
inputs_series = tf.split(1, truncated_backprop_length, batchX_placeholder)
labels_series = tf.unpack(batchY_placeholder, axis=1)

##
cell = tf.nn.rnn_cell.BasicRNNCell(state_size)
states_series, current_state = tf.nn.rnn(cell, inputs_series, init_state)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     489                 as_ref=input_arg.is_ref,
# --> 490                 preferred_dtype=default_dtype)
#     491           except TypeError as err:
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     740         if ret is None:
# --> 741           ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     742
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _TensorTensorConversionFunction(t, dtype, name, as_ref)
#     613         "Tensor conversion requested dtype %s for Tensor with dtype %s: %r"
# --> 614         % (dtype.name, t.dtype.name, str(t)))
#     615   return t
#
# ValueError: Tensor conversion requested dtype int32 for Tensor with dtype float32: 'Tensor("Placeholder:0", shape=(5, 15), dtype=float32)'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7f0c996919b9> in <module>()
#       2
#       3 # Unpack columns
# ----> 4 inputs_series = tf.split(1, truncated_backprop_length, batchX_placeholder)
#       5 labels_series = tf.unpack(batchY_placeholder, axis=1)
#       6
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/ops/array_ops.py in split(value, num_or_size_splits, axis, num, name)
#    1212   if size_splits.get_shape().ndims == 0 and size_splits.dtype.is_integer:
#    1213     return gen_array_ops._split(
# -> 1214         split_dim=axis, num_split=num_or_size_splits, value=value, name=name)
#    1215   else:
#    1216     if num is None:
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/ops/gen_array_ops.py in _split(split_dim, value, num_split, name)
#    3259   """
#    3260   result = _op_def_lib.apply_op("Split", split_dim=split_dim, value=value,
# -> 3261                                 num_split=num_split, name=name)
#    3262   return result
#    3263
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     511             if input_arg.type != types_pb2.DT_INVALID:
#     512               raise TypeError("%s expected type of %s." %
# --> 513                               (prefix, dtypes.as_dtype(input_arg.type).name))
#     514             else:
#     515               # Update the maps with the default, if needed.
#
# TypeError: Input 'split_dim' of 'Split' Op has type float32 that does not match expected type of int32.

# %%
logits_series = [tf.matmul(state, W2) + b2 for state in states_series] #Broadcasted addition
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels) for logits, labels in zip(logits_series,labels_series)]
total_loss = tf.reduce_mean(losses)

train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)

# %%
def plot(loss_list, predictions_series, batchX, batchY):
    plt.subplot(2, 3, 1)
    plt.cla()
    plt.plot(loss_list)

    for batch_series_idx in range(5):
        one_hot_output_series = np.array(predictions_series)[:, batch_series_idx, :]
        single_output_series = np.array([(1 if out[0] < 0.5 else 0) for out in one_hot_output_series])

        plt.subplot(2, 3, batch_series_idx + 2)
        plt.cla()
        plt.axis([0, truncated_backprop_length, 0, 2])
        left_offset = range(truncated_backprop_length)
        plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
        plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
        plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")

    plt.draw()
    plt.pause(0.0001)

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    plt.ion()
    plt.figure()
    plt.show()
    loss_list = []

    for epoch_idx in range(num_epochs):
        x,y = generateData()
        _current_state = np.zeros((batch_size, state_size))

        print("New data, epoch", epoch_idx)

        for batch_idx in range(num_batches):
            start_idx = batch_idx * truncated_backprop_length
            end_idx = start_idx + truncated_backprop_length

            batchX = x[:,start_idx:end_idx]
            batchY = y[:,start_idx:end_idx]

            _total_loss, _train_step, _current_state, _predictions_series = sess.run(
                [total_loss, train_step, current_state, predictions_series],
                feed_dict={
                    batchX_placeholder:batchX,
                    batchY_placeholder:batchY,
                    init_state:_current_state
                })

            loss_list.append(_total_loss)

            if batch_idx%100 == 0:
                print("Step",batch_idx, "Loss", _total_loss)
                plot(loss_list, _predictions_series, batchX, batchY)

plt.ioff()
plt.show()
# Out:
# WARNING:tensorflow:From /home/pankaj/.local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# New data, epoch 0
# Step 0 Loss 0.801324
# Step 100 Loss 0.030007
# Step 200 Loss 0.00762552
# Step 300 Loss 0.00478035
# Step 400 Loss 0.00320071
# Step 500 Loss 0.0024501
# Step 600 Loss 0.00198121
# New data, epoch 1
# Step 0 Loss 0.203923
# Step 100 Loss 0.00188238
# Step 200 Loss 0.00135891
# Step 300 Loss 0.00140896
# Step 400 Loss 0.00124181
# Step 500 Loss 0.00095472
# Step 600 Loss 0.000871675
# New data, epoch 2
# Step 0 Loss 0.450976
# Step 100 Loss 0.000972115
# Step 200 Loss 0.000908751
# Step 300 Loss 0.00071608
# Step 400 Loss 0.000624352
# Step 500 Loss 0.000704389
# Step 600 Loss 0.000499806
# New data, epoch 3
# Step 0 Loss 0.20867
# Step 100 Loss 0.000636932
# Step 200 Loss 0.000479377
# Step 300 Loss 0.000538758
# Step 400 Loss 0.000486701
# Step 500 Loss 0.000506771
# Step 600 Loss 0.00037764
# New data, epoch 4
# Step 0 Loss 0.506985
# Step 100 Loss 0.00086135
# Step 200 Loss 0.00075411
# Step 300 Loss 0.000603927
# Step 400 Loss 0.000610625
# Step 500 Loss 0.000665224
# Step 600 Loss 0.000597131
# New data, epoch 5
# Step 0 Loss 0.477591
# Step 100 Loss 0.000563826
# Step 200 Loss 0.000455702
# Step 300 Loss 0.000518372
# Step 400 Loss 0.000489937
# Step 500 Loss 0.000414719
# Step 600 Loss 0.000452639
# New data, epoch 6
# Step 0 Loss 0.180837
# Step 100 Loss 0.000420428
# Step 200 Loss 0.00049203
# Step 300 Loss 0.000373315
# Step 400 Loss 0.000373159
# Step 500 Loss 0.000378578
# Step 600 Loss 0.000404591
# New data, epoch 7
# Step 0 Loss 0.383979
# Step 100 Loss 0.000396095
# Step 200 Loss 0.000402672
# Step 300 Loss 0.00035281
# Step 400 Loss 0.000328804
# Step 500 Loss 0.000312011
# Step 600 Loss 0.000296036
# New data, epoch 8
# Step 0 Loss 0.482031
# Step 100 Loss 0.000284355
# Step 200 Loss 0.000332944
# Step 300 Loss 0.000282244
# Step 400 Loss 0.000304449
# Step 500 Loss 0.000295182
# Step 600 Loss 0.000257767
# New data, epoch 9
# Step 0 Loss 0.1235
# Step 100 Loss 0.000254253
# Step 200 Loss 0.000251425
# Step 300 Loss 0.000240966
# Step 400 Loss 0.000261619
# Step 500 Loss 0.000244416
# Step 600 Loss 0.000263144
# New data, epoch 10
# Step 0 Loss 0.319811
# Step 100 Loss 0.000228735
# Step 200 Loss 0.000199623
# Step 300 Loss 0.000213204
# Step 400 Loss 0.000218165
# Step 500 Loss 0.000198976
# Step 600 Loss 0.000212125
# New data, epoch 11
# Step 0 Loss 0.0889421
# Step 100 Loss 0.000182338
# Step 200 Loss 0.000228709
# Step 300 Loss 0.000221685
# Step 400 Loss 0.000209317
# Step 500 Loss 0.000142458
# Step 600 Loss 0.000166364
# New data, epoch 12
# Step 0 Loss 0.331062
# Step 100 Loss 0.000172726
# Step 200 Loss 0.000164344
# Step 300 Loss 0.000175486
# Step 400 Loss 0.000180107
# Step 500 Loss 0.000168076
# Step 600 Loss 0.000181547
# New data, epoch 13
# Step 0 Loss 0.307764
# Step 100 Loss 0.000167767
# Step 200 Loss 0.000186772
# Step 300 Loss 0.00018619
# Step 400 Loss 0.00016607
# Step 500 Loss 0.000171725
# Step 600 Loss 0.000146707
# New data, epoch 14
# Step 0 Loss 0.315956
# Step 100 Loss 0.000167176
# Step 200 Loss 0.000176637
# Step 300 Loss 0.000151347
# Step 400 Loss 0.000181413
# Step 500 Loss 0.000152409
# Step 600 Loss 0.000160341
# New data, epoch 15
# Step 0 Loss 0.476708
# Step 100 Loss 0.000138002
# Step 200 Loss 0.0001663
# Step 300 Loss 0.000144944
# Step 400 Loss 0.000141443
# Step 500 Loss 0.000144022
# Step 600 Loss 0.000136313
# New data, epoch 16
# Step 0 Loss 0.198199
# Step 100 Loss 0.000161547
# Step 200 Loss 0.000158139
# Step 300 Loss 0.000154122
# Step 400 Loss 0.000170183
# Step 500 Loss 0.000133124
# Step 600 Loss 0.000149552
# New data, epoch 17
# Step 0 Loss 0.341419
# Step 100 Loss 0.000138502
# Step 200 Loss 0.000144725
# Step 300 Loss 0.000139164
# Step 400 Loss 0.000126619
# Step 500 Loss 0.000130583
# Step 600 Loss 0.000140762
# New data, epoch 18
# Step 0 Loss 0.250051
# Step 100 Loss 0.000130944
# Step 200 Loss 0.000119277
# Step 300 Loss 0.000120367
# Step 400 Loss 0.000109387
# Step 500 Loss 0.000121904
# Step 600 Loss 0.000108964
# New data, epoch 19
# Step 0 Loss 0.298685
# Step 100 Loss 0.000112104
# Step 200 Loss 0.000128299
# Step 300 Loss 0.0001279
# Step 400 Loss 0.000115943
# Step 500 Loss 0.000122458
# Step 600 Loss 0.0001154
# New data, epoch 20
# Step 0 Loss 0.207922
# Step 100 Loss 0.000123998
# Step 200 Loss 0.000127256
# Step 300 Loss 0.00011061
# Step 400 Loss 0.000101759
# Step 500 Loss 0.000115104
# Step 600 Loss 0.000110854
# New data, epoch 21
# Step 0 Loss 0.299942
# Step 100 Loss 0.000118422
# Step 200 Loss 0.000128222
# Step 300 Loss 0.000102632
# Step 400 Loss 0.000112189
# Step 500 Loss 0.000106883
# Step 600 Loss 0.000114791
# New data, epoch 22
# Step 0 Loss 0.345772
# Step 100 Loss 0.000129232
# Step 200 Loss 9.75663e-05
# Step 300 Loss 0.000105356
# Step 400 Loss 9.66038e-05
# Step 500 Loss 0.000100153
# Step 600 Loss 9.36064e-05
# New data, epoch 23
# Step 0 Loss 0.327592
# Step 100 Loss 9.50479e-05
# Step 200 Loss 0.000117252
# Step 300 Loss 9.81567e-05
# Step 400 Loss 9.83454e-05
# Step 500 Loss 0.000110543
# Step 600 Loss 0.000106367
# New data, epoch 24
# Step 0 Loss 0.196096
# Step 100 Loss 8.70318e-05
# Step 200 Loss 0.000102627
# Step 300 Loss 0.000104932
# Step 400 Loss 0.000103783
# Step 500 Loss 0.000102814
# Step 600 Loss 0.000101898
# New data, epoch 25
# Step 0 Loss 0.229131
# Step 100 Loss 0.000104949
# Step 200 Loss 9.12542e-05
# Step 300 Loss 9.68203e-05
# Step 400 Loss 9.26976e-05
# Step 500 Loss 8.73813e-05
# Step 600 Loss 9.64529e-05
# New data, epoch 26
# Step 0 Loss 0.383883
# Step 100 Loss 9.93704e-05
# Step 200 Loss 9.9455e-05
# Step 300 Loss 9.33934e-05
# Step 400 Loss 9.76862e-05
# Step 500 Loss 8.63736e-05
# Step 600 Loss 7.90533e-05
# New data, epoch 27
# Step 0 Loss 0.239533
# Step 100 Loss 9.00311e-05
# Step 200 Loss 8.76738e-05
# Step 300 Loss 8.84274e-05
# Step 400 Loss 0.000104234
# Step 500 Loss 8.54125e-05
# Step 600 Loss 9.54155e-05
# New data, epoch 28
# Step 0 Loss 0.301813
# Step 100 Loss 8.15075e-05
# Step 200 Loss 9.58411e-05
# Step 300 Loss 8.76164e-05
# Step 400 Loss 9.33317e-05
# Step 500 Loss 8.29106e-05
# Step 600 Loss 8.23991e-05
# New data, epoch 29
# Step 0 Loss 0.138364
# Step 100 Loss 8.59799e-05
# Step 200 Loss 8.25406e-05
# Step 300 Loss 8.11483e-05
# Step 400 Loss 7.93952e-05
# Step 500 Loss 7.04507e-05
# Step 600 Loss 7.46211e-05
# New data, epoch 30
# Step 0 Loss 0.184081
# Step 100 Loss 7.91044e-05
# Step 200 Loss 8.43984e-05
# Step 300 Loss 7.24278e-05
# Step 400 Loss 8.8241e-05
# Step 500 Loss 7.85564e-05
# Step 600 Loss 8.70255e-05
# New data, epoch 31
# Step 0 Loss 0.114935
# Step 100 Loss 6.9878e-05
# Step 200 Loss 7.29393e-05
# Step 300 Loss 6.88472e-05
# Step 400 Loss 8.49399e-05
# Step 500 Loss 6.85643e-05
# Step 600 Loss 7.36708e-05
# New data, epoch 32
# Step 0 Loss 0.166547
# Step 100 Loss 7.72942e-05
# Step 200 Loss 8.03695e-05
# Step 300 Loss 7.31126e-05
# Step 400 Loss 7.40297e-05
# Step 500 Loss 6.66394e-05
# Step 600 Loss 8.30523e-05
# New data, epoch 33
# Step 0 Loss 0.0991815
# Step 100 Loss 7.23275e-05
# Step 200 Loss 6.36864e-05
# Step 300 Loss 7.94301e-05
# Step 400 Loss 7.02551e-05
# Step 500 Loss 7.12263e-05
# Step 600 Loss 8.29998e-05
# New data, epoch 34
# Step 0 Loss 0.209774
# Step 100 Loss 7.56255e-05
# Step 200 Loss 6.87804e-05
# Step 300 Loss 7.25026e-05
# Step 400 Loss 7.89947e-05
# Step 500 Loss 7.99834e-05
# Step 600 Loss 8.11324e-05
# New data, epoch 35
# Step 0 Loss 0.257147
# Step 100 Loss 7.42792e-05
# Step 200 Loss 7.27514e-05
# Step 300 Loss 7.23627e-05
# Step 400 Loss 7.4308e-05
# Step 500 Loss 5.92459e-05
# Step 600 Loss 7.67953e-05
# New data, epoch 36
# Step 0 Loss 0.622032
# Step 100 Loss 6.92825e-05
# Step 200 Loss 6.51378e-05
# Step 300 Loss 7.50772e-05
# Step 400 Loss 7.36354e-05
# Step 500 Loss 6.64791e-05
# Step 600 Loss 7.21306e-05
# New data, epoch 37
# Step 0 Loss 0.0795314
# Step 100 Loss 6.47833e-05
# Step 200 Loss 7.39392e-05
# Step 300 Loss 6.48974e-05
# Step 400 Loss 7.65315e-05
# Step 500 Loss 5.85864e-05
# Step 600 Loss 5.75454e-05
# New data, epoch 38
# Step 0 Loss 0.481137
# Step 100 Loss 6.47558e-05
# Step 200 Loss 6.99978e-05
# Step 300 Loss 7.03284e-05
# Step 400 Loss 6.10878e-05
# Step 500 Loss 5.50389e-05
# Step 600 Loss 6.32892e-05
# New data, epoch 39
# Step 0 Loss 0.179498
# Step 100 Loss 7.54301e-05
# Step 200 Loss 8.04077e-05
# Step 300 Loss 6.74865e-05
# Step 400 Loss 6.86009e-05
# Step 500 Loss 5.74738e-05
# Step 600 Loss 6.00281e-05
# New data, epoch 40
# Step 0 Loss 0.241257
# Step 100 Loss 6.36705e-05
# Step 200 Loss 6.89012e-05
# Step 300 Loss 7.67683e-05
# Step 400 Loss 5.8631e-05
# Step 500 Loss 6.50375e-05
# Step 600 Loss 7.20479e-05
# New data, epoch 41
# Step 0 Loss 0.12751
# Step 100 Loss 8.64822e-05
# Step 200 Loss 6.12105e-05
# Step 300 Loss 5.88821e-05
# Step 400 Loss 5.74963e-05
# Step 500 Loss 5.85341e-05
# Step 600 Loss 5.7992e-05
# New data, epoch 42
# Step 0 Loss 0.177107
# Step 100 Loss 6.84895e-05
# Step 200 Loss 6.21084e-05
# Step 300 Loss 5.17681e-05
# Step 400 Loss 5.73247e-05
# Step 500 Loss 6.05732e-05
# Step 600 Loss 5.86946e-05
# New data, epoch 43
# Step 0 Loss 0.166285
# Step 100 Loss 5.90823e-05
# Step 200 Loss 5.60325e-05
# Step 300 Loss 6.3982e-05
# Step 400 Loss 6.17172e-05
# Step 500 Loss 6.28011e-05
# Step 600 Loss 5.58258e-05
# New data, epoch 44
# Step 0 Loss 0.259461
# Step 100 Loss 6.70134e-05
# Step 200 Loss 6.46738e-05
# Step 300 Loss 6.04255e-05
# Step 400 Loss 5.06463e-05
# Step 500 Loss 4.9076e-05
# Step 600 Loss 5.73119e-05
# New data, epoch 45
# Step 0 Loss 0.229137
# Step 100 Loss 6.30429e-05
# Step 200 Loss 6.21702e-05
# Step 300 Loss 7.46923e-05
# Step 400 Loss 6.44274e-05
# Step 500 Loss 5.33958e-05
# Step 600 Loss 6.60006e-05
# New data, epoch 46
# Step 0 Loss 0.296
# Step 100 Loss 5.95051e-05
# Step 200 Loss 5.71163e-05
# Step 300 Loss 5.04411e-05
# Step 400 Loss 6.3631e-05
# Step 500 Loss 5.25978e-05
# Step 600 Loss 6.15238e-05
# New data, epoch 47
# Step 0 Loss 0.24686
# Step 100 Loss 7.25137e-05
# Step 200 Loss 7.59124e-05
# Step 300 Loss 6.67635e-05
# Step 400 Loss 6.77215e-05
# Step 500 Loss 7.5358e-05
# Step 600 Loss 6.23623e-05
# New data, epoch 48
# Step 0 Loss 0.169464
# Step 100 Loss 7.15761e-05
# Step 200 Loss 6.60494e-05
# Step 300 Loss 6.30712e-05
# Step 400 Loss 6.07524e-05
# Step 500 Loss 6.83225e-05
# Step 600 Loss 5.87594e-05
# New data, epoch 49
# Step 0 Loss 0.294045
# Step 100 Loss 5.61465e-05
# Step 200 Loss 6.1021e-05
# Step 300 Loss 5.70411e-05
# Step 400 Loss 5.53074e-05
# Step 500 Loss 5.71161e-05
# Step 600 Loss 5.49767e-05
# New data, epoch 50
# Step 0 Loss 0.185801
# Step 100 Loss 5.18808e-05
# Step 200 Loss 5.74531e-05
# Step 300 Loss 5.69716e-05
# Step 400 Loss 5.16092e-05
# Step 500 Loss 5.60481e-05
# Step 600 Loss 4.88659e-05
# New data, epoch 51
# Step 0 Loss 0.240029
# Step 100 Loss 5.64615e-05
# Step 200 Loss 6.39823e-05
# Step 300 Loss 5.639e-05
# Step 400 Loss 5.63153e-05
# Step 500 Loss 4.97719e-05
# Step 600 Loss 5.6042e-05
# New data, epoch 52
# Step 0 Loss 0.170217
# Step 100 Loss 6.006e-05
# Step 200 Loss 5.62392e-05
# Step 300 Loss 5.2412e-05
# Step 400 Loss 5.16762e-05
# Step 500 Loss 4.99914e-05
# Step 600 Loss 5.24041e-05
# New data, epoch 53
# Step 0 Loss 0.116181
# Step 100 Loss 4.95146e-05
# Step 200 Loss 5.46752e-05
# Step 300 Loss 4.44731e-05
# Step 400 Loss 5.29142e-05
# Step 500 Loss 6.00043e-05
# Step 600 Loss 4.4904e-05
# New data, epoch 54
# Step 0 Loss 0.208512
# Step 100 Loss 6.17892e-05
# Step 200 Loss 5.21085e-05
# Step 300 Loss 4.97801e-05
# Step 400 Loss 5.16349e-05
# Step 500 Loss 4.6417e-05
# Step 600 Loss 5.31686e-05
# New data, epoch 55
# Step 0 Loss 0.172878
# Step 100 Loss 4.63486e-05
# Step 200 Loss 4.76788e-05
# Step 300 Loss 4.90472e-05
# Step 400 Loss 5.25741e-05
# Step 500 Loss 4.27518e-05
# Step 600 Loss 4.93015e-05
# New data, epoch 56
# Step 0 Loss 0.24031
# Step 100 Loss 4.99928e-05
# Step 200 Loss 5.94798e-05
# Step 300 Loss 5.04394e-05
# Step 400 Loss 5.17204e-05
# Step 500 Loss 5.36103e-05
# Step 600 Loss 5.69798e-05
# New data, epoch 57
# Step 0 Loss 0.482347
# Step 100 Loss 5.5745e-05
# Step 200 Loss 5.00121e-05
# Step 300 Loss 5.49105e-05
# Step 400 Loss 5.76379e-05
# Step 500 Loss 5.00725e-05
# Step 600 Loss 5.03538e-05
# New data, epoch 58
# Step 0 Loss 0.286619
# Step 100 Loss 5.07686e-05
# Step 200 Loss 5.48056e-05
# Step 300 Loss 5.42111e-05
# Step 400 Loss 7.05191e-05
# Step 500 Loss 5.35151e-05
# Step 600 Loss 4.58941e-05
# New data, epoch 59
# Step 0 Loss 0.273472
# Step 100 Loss 5.9065e-05
# Step 200 Loss 5.78794e-05
# Step 300 Loss 5.54222e-05
# Step 400 Loss 4.6754e-05
# Step 500 Loss 5.31098e-05
# Step 600 Loss 5.87614e-05
# New data, epoch 60
# Step 0 Loss 0.107473
# Step 100 Loss 4.69129e-05
# Step 200 Loss 5.3736e-05
# Step 300 Loss 4.82384e-05
# Step 400 Loss 4.8793e-05
# Step 500 Loss 5.338e-05
# Step 600 Loss 4.99582e-05
# New data, epoch 61
# Step 0 Loss 0.201417
# Step 100 Loss 5.04302e-05
# Step 200 Loss 4.96657e-05
# Step 300 Loss 5.06892e-05
# Step 400 Loss 4.89648e-05
# Step 500 Loss 4.22656e-05
# Step 600 Loss 4.58702e-05
# New data, epoch 62
# Step 0 Loss 0.188127
# Step 100 Loss 4.74787e-05
# Step 200 Loss 4.19843e-05
# Step 300 Loss 4.55253e-05
# Step 400 Loss 4.89122e-05
# Step 500 Loss 5.08735e-05
# Step 600 Loss 4.80571e-05
# New data, epoch 63
# Step 0 Loss 0.266347
# Step 100 Loss 6.09038e-05
# Step 200 Loss 4.81048e-05
# Step 300 Loss 5.08401e-05
# Step 400 Loss 4.56159e-05
# Step 500 Loss 4.15392e-05
# Step 600 Loss 4.05506e-05
# New data, epoch 64
# Step 0 Loss 0.168921
# Step 100 Loss 4.20954e-05
# Step 200 Loss 4.98625e-05
# Step 300 Loss 4.65869e-05
# Step 400 Loss 4.10337e-05
# Step 500 Loss 4.95634e-05
# Step 600 Loss 4.63483e-05
# New data, epoch 65
# Step 0 Loss 0.287715
# Step 100 Loss 4.50229e-05
# Step 200 Loss 4.96797e-05
# Step 300 Loss 4.39422e-05
# Step 400 Loss 5.45432e-05
# Step 500 Loss 4.63374e-05
# Step 600 Loss 3.90103e-05
# New data, epoch 66
# Step 0 Loss 0.180017
# Step 100 Loss 5.00707e-05
# Step 200 Loss 4.75501e-05
# Step 300 Loss 4.70606e-05
# Step 400 Loss 3.61321e-05
# Step 500 Loss 4.86435e-05
# Step 600 Loss 4.42839e-05
# New data, epoch 67
# Step 0 Loss 0.142208
# Step 100 Loss 4.13531e-05
# Step 200 Loss 4.61784e-05
# Step 300 Loss 3.98703e-05
# Step 400 Loss 4.98751e-05
# Step 500 Loss 4.74784e-05
# Step 600 Loss 4.78822e-05
# New data, epoch 68
# Step 0 Loss 0.235038
# Step 100 Loss 4.24197e-05
# Step 200 Loss 4.98816e-05
# Step 300 Loss 4.85941e-05
# Step 400 Loss 5.0527e-05
# Step 500 Loss 4.57651e-05
# Step 600 Loss 6.11976e-05
# New data, epoch 69
# Step 0 Loss 0.224036
# Step 100 Loss 3.95095e-05
# Step 200 Loss 4.83003e-05
# Step 300 Loss 4.44921e-05
# Step 400 Loss 4.93572e-05
# Step 500 Loss 4.4268e-05
# Step 600 Loss 3.98194e-05
# New data, epoch 70
# Step 0 Loss 0.182737
# Step 100 Loss 4.96163e-05
# Step 200 Loss 4.23863e-05
# Step 300 Loss 4.42012e-05
# Step 400 Loss 4.79077e-05
# Step 500 Loss 3.68092e-05
# Step 600 Loss 3.69808e-05
# New data, epoch 71
# Step 0 Loss 0.180878
# Step 100 Loss 3.24066e-05
# Step 200 Loss 4.58128e-05
# Step 300 Loss 3.87592e-05
# Step 400 Loss 4.56968e-05
# Step 500 Loss 4.72687e-05
# Step 600 Loss 3.95492e-05
# New data, epoch 72
# Step 0 Loss 0.20741
# Step 100 Loss 4.02518e-05
# Step 200 Loss 3.82491e-05
# Step 300 Loss 4.4028e-05
# Step 400 Loss 4.34845e-05
# Step 500 Loss 4.7682e-05
# Step 600 Loss 4.38373e-05
# New data, epoch 73
# Step 0 Loss 0.129359
# Step 100 Loss 4.11274e-05
# Step 200 Loss 5.11483e-05
# Step 300 Loss 3.99451e-05
# Step 400 Loss 3.45793e-05
# Step 500 Loss 3.76054e-05
# Step 600 Loss 3.89485e-05
# New data, epoch 74
# Step 0 Loss 0.17662
# Step 100 Loss 4.34638e-05
# Step 200 Loss 3.93299e-05
# Step 300 Loss 3.54758e-05
# Step 400 Loss 4.82652e-05
# Step 500 Loss 4.22528e-05
# Step 600 Loss 3.88674e-05
# New data, epoch 75
# Step 0 Loss 0.134702
# Step 100 Loss 4.42569e-05
# Step 200 Loss 3.68759e-05
# Step 300 Loss 4.75166e-05
# Step 400 Loss 3.23891e-05
# Step 500 Loss 4.22559e-05
# Step 600 Loss 4.30013e-05
# New data, epoch 76
# Step 0 Loss 0.164219
# Step 100 Loss 3.36128e-05
# Step 200 Loss 4.04297e-05
# Step 300 Loss 3.64308e-05
# Step 400 Loss 3.40594e-05
# Step 500 Loss 3.70348e-05
# Step 600 Loss 3.56187e-05
# New data, epoch 77
# Step 0 Loss 0.103446
# Step 100 Loss 4.24227e-05
# Step 200 Loss 4.64055e-05
# Step 300 Loss 3.93854e-05
# Step 400 Loss 3.75545e-05
# Step 500 Loss 4.49879e-05
# Step 600 Loss 4.06983e-05
# New data, epoch 78
# Step 0 Loss 0.250524
# Step 100 Loss 4.17901e-05
# Step 200 Loss 3.52516e-05
# Step 300 Loss 4.28598e-05
# Step 400 Loss 3.57252e-05
# Step 500 Loss 2.94423e-05
# Step 600 Loss 3.37701e-05
# New data, epoch 79
# Step 0 Loss 0.255962
# Step 100 Loss 3.59873e-05
# Step 200 Loss 4.79805e-05
# Step 300 Loss 3.61878e-05
# Step 400 Loss 4.42362e-05
# Step 500 Loss 3.50752e-05
# Step 600 Loss 3.5029e-05
# New data, epoch 80
# Step 0 Loss 0.233982
# Step 100 Loss 3.69728e-05
# Step 200 Loss 3.56521e-05
# Step 300 Loss 3.20029e-05
# Step 400 Loss 3.16039e-05
# Step 500 Loss 3.92997e-05
# Step 600 Loss 4.12721e-05
# New data, epoch 81
# Step 0 Loss 0.163908
# Step 100 Loss 4.25148e-05
# Step 200 Loss 4.23527e-05
# Step 300 Loss 3.44871e-05
# Step 400 Loss 2.8581e-05
# Step 500 Loss 3.68472e-05
# Step 600 Loss 3.83857e-05
# New data, epoch 82
# Step 0 Loss 0.197234
# Step 100 Loss 3.81475e-05
# Step 200 Loss 3.91043e-05
# Step 300 Loss 3.28373e-05
# Step 400 Loss 3.47016e-05
# Step 500 Loss 4.25355e-05
# Step 600 Loss 4.80809e-05
# New data, epoch 83
# Step 0 Loss 0.225384
# Step 100 Loss 3.42407e-05
# Step 200 Loss 3.6461e-05
# Step 300 Loss 3.99894e-05
# Step 400 Loss 3.43409e-05
# Step 500 Loss 3.61734e-05
# Step 600 Loss 3.56203e-05
# New data, epoch 84
# Step 0 Loss 0.184428
# Step 100 Loss 4.05029e-05
# Step 200 Loss 3.13497e-05
# Step 300 Loss 2.99558e-05
# Step 400 Loss 4.49944e-05
# Step 500 Loss 3.8556e-05
# Step 600 Loss 4.14868e-05
# New data, epoch 85
# Step 0 Loss 0.146178
# Step 100 Loss 3.57269e-05
# Step 200 Loss 3.63308e-05
# Step 300 Loss 4.20701e-05
# Step 400 Loss 2.93821e-05
# Step 500 Loss 3.1283e-05
# Step 600 Loss 3.1693e-05
# New data, epoch 86
# Step 0 Loss 0.119813
# Step 100 Loss 3.78169e-05
# Step 200 Loss 3.7232e-05
# Step 300 Loss 3.47875e-05
# Step 400 Loss 3.45872e-05
# Step 500 Loss 2.86365e-05
# Step 600 Loss 3.32394e-05
# New data, epoch 87
# Step 0 Loss 0.1853
# Step 100 Loss 3.44268e-05
# Step 200 Loss 4.61722e-05
# Step 300 Loss 4.10306e-05
# Step 400 Loss 3.40612e-05
# Step 500 Loss 3.15325e-05
# Step 600 Loss 3.46349e-05
# New data, epoch 88
# Step 0 Loss 0.152039
# Step 100 Loss 3.83906e-05
# Step 200 Loss 3.43901e-05
# Step 300 Loss 3.65057e-05
# Step 400 Loss 3.59096e-05
# Step 500 Loss 3.76245e-05
# Step 600 Loss 3.4584e-05
# New data, epoch 89
# Step 0 Loss 0.220203
# Step 100 Loss 3.34015e-05
# Step 200 Loss 3.31997e-05
# Step 300 Loss 3.02053e-05
# Step 400 Loss 3.63165e-05
# Step 500 Loss 3.04564e-05
# Step 600 Loss 2.73825e-05
# New data, epoch 90
# Step 0 Loss 0.170412
# Step 100 Loss 3.9767e-05
# Step 200 Loss 3.22126e-05
# Step 300 Loss 3.1046e-05
# Step 400 Loss 3.59684e-05
# Step 500 Loss 3.07361e-05
# Step 600 Loss 3.1596e-05
# New data, epoch 91
# Step 0 Loss 0.133128
# Step 100 Loss 3.1472e-05
# Step 200 Loss 3.95047e-05
# Step 300 Loss 3.72287e-05
# Step 400 Loss 2.97364e-05
# Step 500 Loss 3.37369e-05
# Step 600 Loss 4.02294e-05
# New data, epoch 92
# Step 0 Loss 0.216149
# Step 100 Loss 4.05395e-05
# Step 200 Loss 3.11288e-05
# Step 300 Loss 3.64405e-05
# Step 400 Loss 3.21475e-05
# Step 500 Loss 3.13385e-05
# Step 600 Loss 2.778e-05
# New data, epoch 93
# Step 0 Loss 0.166855
# Step 100 Loss 2.90308e-05
# Step 200 Loss 3.92568e-05
# Step 300 Loss 3.04994e-05
# Step 400 Loss 3.78312e-05
# Step 500 Loss 3.95175e-05
# Step 600 Loss 3.669e-05
# New data, epoch 94
# Step 0 Loss 0.192756
# Step 100 Loss 3.11415e-05
# Step 200 Loss 3.40579e-05
# Step 300 Loss 2.93438e-05
# Step 400 Loss 2.99032e-05
# Step 500 Loss 2.91563e-05
# Step 600 Loss 3.1178e-05
# New data, epoch 95
# Step 0 Loss 0.187991
# Step 100 Loss 4.18475e-05
# Step 200 Loss 3.53788e-05
# Step 300 Loss 3.19822e-05
# Step 400 Loss 3.89468e-05
# Step 500 Loss 3.3338e-05
# Step 600 Loss 3.20474e-05
# New data, epoch 96
# Step 0 Loss 0.253086
# Step 100 Loss 3.13417e-05
# Step 200 Loss 3.07775e-05
# Step 300 Loss 3.24734e-05
# Step 400 Loss 3.33443e-05
# Step 500 Loss 2.82821e-05
# Step 600 Loss 3.62339e-05
# New data, epoch 97
# Step 0 Loss 0.112867
# Step 100 Loss 3.17231e-05
# Step 200 Loss 3.57617e-05
# Step 300 Loss 2.92119e-05
# Step 400 Loss 2.92024e-05
# Step 500 Loss 3.70746e-05
# Step 600 Loss 3.40897e-05
# New data, epoch 98
# Step 0 Loss 0.16787
# Step 100 Loss 2.54832e-05
# Step 200 Loss 3.59318e-05
# Step 300 Loss 2.55881e-05
# Step 400 Loss 3.10445e-05
# Step 500 Loss 3.16484e-05
# Step 600 Loss 3.49051e-05
# New data, epoch 99
# Step 0 Loss 0.24861
# Step 100 Loss 2.98778e-05
# Step 200 Loss 3.45348e-05
# Step 300 Loss 3.0833e-05
# Step 400 Loss 2.49317e-05
# Step 500 Loss 3.19583e-05
# Step 600 Loss 3.51959e-05
